# %% [markdown]
# # Excercises
# # 1. Tune the network
# Run the experiment below, explore the different parameters (see suggestions below) and study the result with tensorboard.
# Make a single page (1 a4) report of your findings. Use your visualisation skills to communicate your most important findings.

# %%
from mads_datasets import DatasetFactoryProvider, DatasetType

from mltrainer.preprocessors import BasePreprocessor
from mltrainer import imagemodels, Trainer, TrainerSettings, ReportTypes, metrics

import torch.optim as optim
from torch import nn
from tomlserializer import TOMLSerializer

# %% [markdown]
# We will be using `tomlserializer` to easily keep track of our experiments, and to easily save the different things we did during our experiments.
# It can export things like settings and models to a simple `toml` file, which can be easily shared, checked and modified.
#
# First, we need the data.

# %%
fashionfactory = DatasetFactoryProvider.create_factory(DatasetType.FASHION)
preprocessor = BasePreprocessor()
streamers = fashionfactory.create_datastreamer(batchsize=64, preprocessor=preprocessor)
train = streamers["train"]
valid = streamers["valid"]
trainstreamer = train.stream()
validstreamer = valid.stream()
# Out:
# 2026-03-21 11:31:13.544 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /home/fblaak/.cache/mads_datasets/fashionmnist
# 2026-03-21 11:31:13.546 | INFO     | mads_datasets.base:download_data:124 - File already exists at /home/fblaak/.cache/mads_datasets/fashionmnist/fashionmnist.pt

# %% [markdown]
# We need a way to determine how well our model is performing. We will use accuracy as a metric.

# %%
accuracy = metrics.Accuracy()

# %% [markdown]
# You can set up a single experiment.
#
# - We will show the model batches of 64 images,
# - and for every epoch we will show the model 100 batches (trainsteps=100).
# - then, we will test how well the model is doing on unseen data (teststeps=100).
# - we will report our results during training to tensorboard, and report all configuration to a toml file.
# - we will log the results into a directory called "modellogs", but you could change this to whatever you want.

# %%
import torch
loss_fn = torch.nn.CrossEntropyLoss()

settings = TrainerSettings(
    epochs=3,
    metrics=[accuracy],
    logdir="modellogs",
    train_steps=100,
    valid_steps=100,
    reporttypes=[ReportTypes.TENSORBOARD, ReportTypes.TOML],
)

# %% [markdown]
# We will use a very basic model: a model with three linear layers.

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, num_classes: int, units1: int, units2: int, units3: int) -> None:
        super().__init__()
        self.num_classes = num_classes
        self.units1 = units1
        self.units2 = units2
        self.units3 = units3
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28 * 28, units1),
            nn.ReLU(),
            nn.Linear(units1, units2),
            nn.ReLU(),
            nn.Linear(units2, units3),
            nn.ReLU(),
            nn.Linear(units3, num_classes),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork(
    num_classes=10, units1=256, units2=256, units3=128)

# %% [markdown]
# I developped the `tomlserializer` package, it is a useful tool to save configs, models and settings as a tomlfile; that way it is easy to track what you changed during your experiments.
#
# This package will 1. check if there is a `__dict__` attribute available, and if so, it will use that to extract the parameters that do not start with an underscore, like this:

# %%
{k: v for k, v in model.__dict__.items() if not k.startswith("_")}
# Out:
# {'training': True,
#  'num_classes': 10,
#  'units1': 256,
#  'units2': 256,
#  'units3': 128}

# %% [markdown]
# This means that if you want to add more parameters to the `.toml` file, eg `units3`, you can add them to the class like this:
#
# ```python
# class NeuralNetwork(nn.Module):
#     def __init__(self, num_classes: int, units1: int, units2: int, units3: int) -> None:
#         super().__init__()
#         self.num_classes = num_classes
#         self.units1 = units1
#         self.units2 = units2
#         self.units3 = units3  # <-- add this line
# ```
#
# And then it will be added to the `.toml` file. Check the result for yourself by using the `.save()` method of the `TomlSerializer` class like this:

# %%
tomlserializer = TOMLSerializer()
tomlserializer.save(settings, "settings.toml")
tomlserializer.save(model, "model.toml")

# %% [markdown]
# Check the `settings.toml` and `model.toml` files to see what is in there.

# %% [markdown]
# You can use the `Trainer` class from my `mltrainer` module to train your model. It has the TOMLserializer integrated, so it will automatically save the settings and model to a toml file if you have added `TOML` as a reporttype in the settings.

# %%
trainer = Trainer(
    model=model,
    settings=settings,
    loss_fn=loss_fn,
    optimizer=optim.Adam,
    traindataloader=trainstreamer,
    validdataloader=validstreamer,
    scheduler=optim.lr_scheduler.ReduceLROnPlateau
)
trainer.loop()
# Out:
# 2026-03-21 11:32:03.864 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs/20260321-113203
# 2026-03-21 11:32:05.860 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 100/100 [00:00<00:00, 164.31it/s]
# 2026-03-21 11:32:06.829 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.0043 test 0.6966 metric ['0.7456']
# 100%|██████████| 100/100 [00:00<00:00, 175.98it/s]
# 2026-03-21 11:32:07.633 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.6107 test 0.5540 metric ['0.8063']
# 100%|██████████| 100/100 [00:00<00:00, 121.94it/s]
# 2026-03-21 11:32:08.892 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.5713 test 0.5248 metric ['0.8108']
# 100%|██████████| 3/3 [00:02<00:00,  1.03it/s]

# %% [markdown]
# Now, check in the modellogs directory the results of your experiment.

# %% [markdown]
# We can now loop this with a naive approach, called a grid-search (why do you think i call it naive?).

# %%
units = [256, 128, 64]
for unit1 in units:
    for unit2 in units:
        print(f"Units: {unit1}, {unit2}")
# Out:
# Units: 256, 256
# Units: 256, 128
# Units: 256, 64
# Units: 128, 256
# Units: 128, 128
# Units: 128, 64
# Units: 64, 256
# Units: 64, 128
# Units: 64, 64

# %% [markdown]
# Of course, this might not be the best way to search for a model; some configurations will be better than others (can you predict up front what will be the best configuration?).
#
# So, feel free to improve upon the gridsearch by adding your own logic.

# %%
import torch

units = [256, 128, 64]
loss_fn = torch.nn.CrossEntropyLoss()

settings = TrainerSettings(
    epochs=10,
    metrics=[accuracy],
    logdir="modellogs",
    train_steps=len(train),
    valid_steps=len(valid),
    reporttypes=[ReportTypes.TENSORBOARD, ReportTypes.TOML],
)

for unit1 in units:
    for unit2 in units:
        for unit3 in units:

            model = NeuralNetwork(num_classes=10, units1=unit1, units2=unit2, units3=unit3)

        trainer = Trainer(
            model=model,
            settings=settings,
            loss_fn=loss_fn,
            optimizer=optim.Adam,
            traindataloader=trainstreamer,
            validdataloader=validstreamer,
            scheduler=optim.lr_scheduler.ReduceLROnPlateau
        )
        trainer.loop()
# Out:
# 2026-03-21 11:34:03.184 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs/20260321-113403
# 2026-03-21 11:34:03.185 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 937/937 [00:05<00:00, 157.40it/s]
# 2026-03-21 11:34:09.498 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.5445 test 0.4209 metric ['0.8452']
# 100%|██████████| 937/937 [00:06<00:00, 152.99it/s]
# 2026-03-21 11:34:15.987 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.3732 test 0.4177 metric ['0.8497']
# 100%|██████████| 937/937 [00:04<00:00, 212.44it/s]
# 2026-03-21 11:34:20.756 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3348 test 0.3769 metric ['0.8634']
# 100%|██████████| 937/937 [00:04<00:00, 210.12it/s]
# 2026-03-21 11:34:25.574 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3093 test 0.3691 metric ['0.8692']
# 100%|██████████| 937/937 [00:04<00:00, 208.84it/s]
# 2026-03-21 11:34:30.420 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.2939 test 0.3904 metric ['0.8526']
# 2026-03-21 11:34:30.422 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3691, current loss 0.3904.Counter 1/10.
# 100%|██████████| 937/937 [00:04<00:00, 210.82it/s]
# 2026-03-21 11:34:35.222 | INFO     | mltrainer.trainer:report:209 - Epoch 5 train 0.2785 test 0.3580 metric ['0.8736']
# 100%|██████████| 937/937 [00:04<00:00, 207.48it/s]
# 2026-03-21 11:34:40.095 | INFO     | mltrainer.trainer:report:209 - Epoch 6 train 0.2654 test 0.3680 metric ['0.8669']
# 2026-03-21 11:34:40.097 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3580, current loss 0.3680.Counter 1/10.
# 100%|██████████| 937/937 [00:04<00:00, 213.08it/s]
# 2026-03-21 11:34:44.847 | INFO     | mltrainer.trainer:report:209 - Epoch 7 train 0.2549 test 0.3657 metric ['0.8721']
# 2026-03-21 11:34:44.848 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3580, current loss 0.3657.Counter 2/10.
# 100%|██████████| 937/937 [00:04<00:00, 212.18it/s]
# 2026-03-21 11:34:49.621 | INFO     | mltrainer.trainer:report:209 - Epoch 8 train 0.2459 test 0.3319 metric ['0.8845']
# 100%|██████████| 937/937 [00:04<00:00, 212.35it/s]
# 2026-03-21 11:34:54.386 | INFO     | mltrainer.trainer:report:209 - Epoch 9 train 0.2354 test 0.3222 metric ['0.8856']
# 100%|██████████| 10/10 [00:51<00:00,  5.12s/it]
# 2026-03-21 11:34:54.395 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs/20260321-113454
# 2026-03-21 11:34:54.396 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 937/937 [00:04<00:00, 217.74it/s]
# 2026-03-21 11:34:59.052 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.5620 test 0.4295 metric ['0.8445']
# 100%|██████████| 937/937 [00:04<00:00, 214.76it/s]
# 2026-03-21 11:35:03.768 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.3817 test 0.3891 metric ['0.8608']
# 100%|██████████| 937/937 [00:04<00:00, 206.89it/s]
# 2026-03-21 11:35:08.828 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.3443 test 0.3859 metric ['0.8592']
# 100%|██████████| 937/937 [00:05<00:00, 182.72it/s]
# 2026-03-21 11:35:14.303 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.3114 test 0.3717 metric ['0.8669']
# 100%|██████████| 937/937 [00:04<00:00, 228.72it/s]
# 2026-03-21 11:35:18.801 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0
| INFO     | mltrainer.trainer:report:209 - Epoch 7 train 0.2886 test 0.3900 metric ['0.8639']
# 2026-03-21 11:40:06.497 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3638, current loss 0.3900.Counter 2/10.
# 100%|██████████| 937/937 [00:03<00:00, 299.24it/s]
# 2026-03-21 11:40:09.942 | INFO     | mltrainer.trainer:report:209 - Epoch 8 train 0.2779 test 0.3552 metric ['0.8732']
# 100%|██████████| 937/937 [00:03<00:00, 304.04it/s]
# 2026-03-21 11:40:13.337 | INFO     | mltrainer.trainer:report:209 - Epoch 9 train 0.2712 test 0.3563 metric ['0.8723']
# 2026-03-21 11:40:13.338 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.3552, current loss 0.3563.Counter 1/10.
# 100%|██████████| 10/10 [00:35<00:00,  3.56s/it]

# %% [markdown]
# Because we have set the ReportType to TOML, you will find in every log dir a model.toml and settings.toml file.

# %% [markdown]
# Run the experiment, and study the result with tensorboard.
#
# Locally, it is easy to do that with VS code itself. On the server, you have to take these steps:
#
# - in the terminal, `cd` to the location of the repository
# - activate the python environment for the shell. Note how the correct environment is being activated.
# - run `tensorboard --logdir=modellogs` in the terminal
# - tensorboard will launch at `localhost:6006` and vscode will notify you that the port is forwarded
# - you can either press the `launch` button in VScode or open your local browser at `localhost:6006`

# %%
optimizers = {
    "Adam": optim.Adam,
    "SGD": optim.SGD,
    "RMSprop": optim.RMSprop,
}

learning_rates = [1e-2, 1e-3, 1e-4]

for opt_name, opt_class in optimizers.items():
    for lr in learning_rates:

        settings = TrainerSettings(
            epochs=5,
            metrics=[accuracy],
            logdir="modellogs",
            train_steps=100,
            valid_steps=100,
            optimizer_kwargs={"lr": lr},
            reporttypes=[ReportTypes.TENSORBOARD, ReportTypes.TOML],
        )

        model = NeuralNetwork(num_classes=10, units1=128, units2=64, units3=32)

        # dit wordt automatisch opgeslagen in model.toml
        model.optimizer = opt_name

        trainer = Trainer(
            model=model,
            settings=settings,
            loss_fn=loss_fn,
            optimizer=opt_class,
            traindataloader=trainstreamer,
            validdataloader=validstreamer,
            scheduler=optim.lr_scheduler.ReduceLROnPlateau
        )

        trainer.loop()
# Out:
# 2026-03-21 11:56:29.101 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs/20260321-115629
# 2026-03-21 11:56:29.104 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 100/100 [00:00<00:00, 272.15it/s]
# 2026-03-21 11:56:29.689 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 0.8773 test 0.6333 metric ['0.7672']
# 100%|██████████| 100/100 [00:00<00:00, 285.51it/s]
# 2026-03-21 11:56:30.259 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.6080 test 0.6298 metric ['0.7711']
# 100%|██████████| 100/100 [00:00<00:00, 262.11it/s]
# 2026-03-21 11:56:30.898 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.5293 test 0.5680 metric ['0.7847']
# 100%|██████████| 100/100 [00:00<00:00, 263.31it/s]
# 2026-03-21 11:56:31.530 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.4927 test 0.5379 metric ['0.8114']
# 100%|██████████| 100/100 [00:00<00:00, 281.91it/s]
# 2026-03-21 11:56:32.103 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.4857 test 0.5725 metric ['0.7994']
# 2026-03-21 11:56:32.104 | INFO     | mltrainer.trainer:__call__:252 - best loss: 0.5379, current loss 0.5725.Counter 1/10.
# 100%|██████████| 5/5 [00:02<00:00,  1.67it/s]
# 2026-03-21 11:56:32.108 | INFO     | mltrainer.trainer:dir_add_timestamp:24 - Logging to modellogs/20260321-115632
# 2026-03-21 11:56:32.109 | INFO     | mltrainer.trainer:__init__:68 - Found earlystop_kwargs in settings.Set to None if you dont want earlystopping.
# 100%|██████████| 100/100 [00:00<00:00, 275.33it/s]
# 2026-03-21 11:56:32.693 | INFO     | mltrainer.trainer:report:209 - Epoch 0 train 1.2693 test 0.7925 metric ['0.7141']
# 100%|██████████| 100/100 [00:00<00:00, 278.79it/s]
# 2026-03-21 11:56:33.296 | INFO     | mltrainer.trainer:report:209 - Epoch 1 train 0.7081 test 0.7129 metric ['0.7536']
# 100%|██████████| 100/100 [00:00<00:00, 253.26it/s]
# 2026-03-21 11:56:33.902 | INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.
| INFO     | mltrainer.trainer:report:209 - Epoch 2 train 0.9882 test 0.9313 metric ['0.6923']
# 100%|██████████| 100/100 [00:00<00:00, 293.34it/s]
# 2026-03-21 11:56:53.654 | INFO     | mltrainer.trainer:report:209 - Epoch 3 train 0.8667 test 0.8425 metric ['0.6937']
# 100%|██████████| 100/100 [00:00<00:00, 296.39it/s]
# 2026-03-21 11:56:54.218 | INFO     | mltrainer.trainer:report:209 - Epoch 4 train 0.7914 test 0.7779 metric ['0.7253']
# 100%|██████████| 5/5 [00:02<00:00,  1.77it/s]

# %%
import os
import tomllib
import pandas as pd
from tensorboard.backend.event_processing import event_accumulator

def get_last_scalar(run_path, tag):
    try:
        ea = event_accumulator.EventAccumulator(run_path)
        ea.Reload()
        if tag in ea.scalars.Keys():
            values = ea.scalars.Items(tag)
            if values:
                return values[-1].value
    except Exception as e:
        print(f"Error reading {tag} from {run_path}: {e}")
    return None

logdir = "modellogs"
rows = []

for run in os.listdir(logdir):
    run_path = os.path.join(logdir, run)

    model_file = os.path.join(run_path, "model.toml")
    settings_file = os.path.join(run_path, "settings.toml")

    if os.path.exists(model_file) and os.path.exists(settings_file):
        with open(model_file, "rb") as f:
            model = tomllib.load(f)

        with open(settings_file, "rb") as f:
            settings = tomllib.load(f)

        row = {
            "run": run,
            "optimizer": model["model"].get("optimizer"),
            "units1": model["model"].get("units1"),
            "units2": model["model"].get("units2"),
            "epochs": settings["model"].get("epochs"),
            "learning_rate": settings["model"].get("optimizer_kwargs", {}).get("lr"),
            "weight_decay": settings["model"].get("optimizer_kwargs", {}).get("weight_decay"),
            "train_steps": settings["model"].get("train_steps"),
            "valid_steps": settings["model"].get("valid_steps"),
            "accuracy": get_last_scalar(run_path, "metric/Accuracy"),
            "train_loss": get_last_scalar(run_path, "Loss/train"),
            "test_loss": get_last_scalar(run_path, "Loss/test"),
            "logged_learning_rate": get_last_scalar(run_path, "learning_rate")
        }

        rows.append(row)

df = pd.DataFrame(rows).sort_values("run").reset_index(drop=True)
df
# Out:
#                  run optimizer  units1  units2  epochs  learning_rate  \
# 0    20260307-114607      None     256     256       3          0.001
# 1    20260307-114613      None     256     256       3          0.001
# 2    20260307-114626      None     256     128       3          0.001
# 3    20260307-114641      None     256      64       3          0.001
# 4    20260307-114653      None     128     256       3          0.001
# ..               ...       ...     ...     ...     ...            ...
# 150  20260321-113707      None     128     128      10          0.001
# 151  20260321-113746      None     128      64      10          0.001
# 152  20260321-113825      None      64     256      10          0.001
# 153  20260321-113901      None      64     128      10          0.001
# 154  20260321-113937      None      64      64      10          0.001
#
#      weight_decay  train_steps  valid_steps  accuracy  train_loss  test_loss  \
# 0         0.00001          100          100  0.791719    0.522886   0.570322
# 1         0.00001          937          156  0.871595    0.327041   0.357538
# 2         0.00001          937          156  0.874499    0.332913   0.346354
# 3         0.00001          937          156  0.865685    0.343050   0.369335
# 4         0.00001          937          156  0.867188    0.334989   0.362355
# ..            ...          ...          ...       ...         ...        ...
# 150       0.00001          937          156  0.884816    0.245413   0.324372
# 151       0.00001          937          156  0.870493    0.252809   0.355223
# 152       0.00001          937          156  0.878806    0.253068   0.350586
# 153       0.00001          937          156  0.878706    0.261501   0.339798
# 154       0.00001          937          156  0.872296    0.271229   0.356293
#
#      logged_learning_rate
# 0                   0.001
# 1                   0.001
# 2                   0.001
# 3                   0.001
# 4                   0.001
# ..                    ...
# 150                 0.001
# 151                 0.001
# 152                 0.001
# 153                 0.001
# 154                 0.001
#
# [155 rows x 13 columns]

# %%
# df = df[
#     ["units1", "units2", "epochs", "learning_rate", "accuracy", "train_loss", "test_loss"]
# ].sort_values("accuracy", ascending=False)

df["overfit_gap"] = df["test_loss"] - df["train_loss"]
df["overfit_ratio"] = df["test_loss"] / df["train_loss"]
df["model_size"] = df["units1"] + df["units2"]


# df = df[
#     ["units1","units2","epochs","learning_rate","train_loss","test_loss","accuracy","overfit_gap","overfit_ratio","model_size"]
# ].sort_values("overfit_gap", ascending=False)

df = df[[
    "run","units1","units2","epochs","learning_rate",
    "accuracy","train_loss","test_loss","overfit_ratio"
]].sort_values(
    ["accuracy", "overfit_ratio"],
    ascending=[False, True]
)

df
# Out:
#                  run  units1  units2  epochs  learning_rate  accuracy  \
# 104  20260315-192955     256     128      10         0.0010  0.891827
# 142  20260315-215231     256     256      10         0.0010  0.889123
# 23   20260307-171229     128     128      10         0.0010  0.887921
# 103  20260315-192909     256     256      10         0.0010  0.887320
# 91   20260315-190452     256     256      10         0.0010  0.887220
# ..               ...     ...     ...     ...            ...       ...
# 129  20260315-205335     128      64       5         0.0001  0.138750
# 120  20260315-195907     128      64      10         0.0001  0.100156
# 138  20260315-210343     128      64       5         0.0001  0.052344
# 143  20260315-215324     256     128      10         0.0010       NaN
# 144  20260315-220008     256     256      10         0.0010       NaN
#
#      train_loss  test_loss  overfit_ratio
# 104    0.231121   0.315200       1.363791
# 142    0.233774   0.324006       1.385982
# 23     0.239923   0.321445       1.339785
# 103    0.228913   0.319918       1.397552
# 91     0.226967   0.350016       1.542142
# ..          ...        ...            ...
# 129    2.306764   2.304260       0.998914
# 120    2.302288   2.300206       0.999096
# 138    2.300202   2.298652       0.999326
# 143         NaN        NaN            NaN
# 144         NaN        NaN            NaN
#
# [155 rows x 9 columns]

# %%
filtered = df[df["overfit_ratio"] < 1.5].sort_values("accuracy", ascending=False)

filtered
# Out:
#                  run  units1  units2  epochs  learning_rate  accuracy  \
# 104  20260315-192955     256     128      10         0.0010  0.891827
# 142  20260315-215231     256     256      10         0.0010  0.889123
# 23   20260307-171229     128     128      10         0.0010  0.887921
# 103  20260315-192909     256     256      10         0.0010  0.887320
# 149  20260321-113626     128     256      10         0.0010  0.885917
# ..               ...     ...     ...     ...            ...       ...
# 128  20260315-205332     128      64       5         0.0010  0.187656
# 137  20260315-210340     128      64       5         0.0010  0.165156
# 129  20260315-205335     128      64       5         0.0001  0.138750
# 120  20260315-195907     128      64      10         0.0001  0.100156
# 138  20260315-210343     128      64       5         0.0001  0.052344
#
#      train_loss  test_loss  overfit_ratio
# 104    0.231121   0.315200       1.363791
# 142    0.233774   0.324006       1.385982
# 23     0.239923   0.321445       1.339785
# 103    0.228913   0.319918       1.397552
# 149    0.241090   0.332867       1.380674
# ..          ...        ...            ...
# 128    2.274544   2.271617       0.998713
# 137    2.273357   2.267249       0.997313
# 129    2.306764   2.304260       0.998914
# 120    2.302288   2.300206       0.999096
# 138    2.300202   2.298652       0.999326
#
# [149 rows x 9 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd

heatmap_df = df.pivot_table(
    index="units1",
    columns="units2",
    values="accuracy",
    aggfunc="max"
)

plt.figure(figsize=(8,6))

plt.imshow(heatmap_df, cmap="viridis")

plt.colorbar(label="Accuracy")

plt.xticks(range(len(heatmap_df.columns)), heatmap_df.columns)
plt.yticks(range(len(heatmap_df.index)), heatmap_df.index)

plt.xlabel("units2")
plt.ylabel("units1")
plt.title("Accuracy for different hidden layer sizes")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# maak pivot tabel
heatmap_df = df.pivot_table(
    index="epochs",
    columns="learning_rate",
    values="accuracy",
    aggfunc="max"
)

fig, ax = plt.subplots(figsize=(8,6))

im = ax.imshow(heatmap_df, cmap="viridis")

# cijfers in de cellen
for i in range(len(heatmap_df.index)):
    for j in range(len(heatmap_df.columns)):
        val = heatmap_df.iloc[i, j]
        if not pd.isna(val):
            ax.text(j, i, f"{val:.3f}", ha="center", va="center", color="white")

# labels
ax.set_xticks(range(len(heatmap_df.columns)))
ax.set_yticks(range(len(heatmap_df.index)))

ax.set_xticklabels(heatmap_df.columns)
ax.set_yticklabels(heatmap_df.index)

ax.set_xlabel("learning rate")
ax.set_ylabel("epochs")
ax.set_title("Accuracy for learning rate vs epochs")

plt.colorbar(im, label="accuracy")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

heatmap_df = df.pivot_table(
    index="optimizer",
    columns="learning_rate",
    values="accuracy",
    aggfunc="max"
)

heatmap_df = heatmap_df.sort_index(axis=1)

fig, ax = plt.subplots(figsize=(8, 6))
im = ax.imshow(heatmap_df, cmap="viridis")

for i in range(len(heatmap_df.index)):
    for j in range(len(heatmap_df.columns)):
        val = heatmap_df.iloc[i, j]
        if not pd.isna(val):
            ax.text(j, i, f"{val:.3f}", ha="center", va="center", color="white")

ax.set_xticks(range(len(heatmap_df.columns)))
ax.set_yticks(range(len(heatmap_df.index)))

ax.set_xticklabels(heatmap_df.columns)
ax.set_yticklabels(heatmap_df.index)

ax.set_xlabel("learning rate")
ax.set_ylabel("optimizer")
ax.set_title("Accuracy for optimizer vs learning rate")

plt.colorbar(im, label="accuracy")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 4
#       1 import matplotlib.pyplot as plt
#       2 import pandas as pd
# ----> 4 heatmap_df = df.pivot_table(
#       5     index="optimizer",
#       6     columns="learning_rate",
#       7     values="accuracy",
#       8     aggfunc="max"
#       9 )
#      11 heatmap_df = heatmap_df.sort_index(axis=1)
#      13 fig, ax = plt.subplots(figsize=(8, 6))
#
# File ~/MADS-ML-PORTFOLIO-FBLAAK/portfolio-example-main/.venv/lib/python3.12/site-packages/pandas/core/frame.py:9516, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9499 @Substitution("")
#    9500 @Appender(_shared_docs["pivot_table"])
#    9501 def pivot_table(
#    (...)   9512     sort: bool = True,
#    9513 ) -> DataFrame:
#    9514     from pandas.core.reshape.pivot import pivot_table
# -> 9516     return pivot_table(
#    9517         self,
#    9518         values=values,
#    9519         index=index,
#    9520         columns=columns,
#    9521         aggfunc=aggfunc,
#    9522         fill_value=fill_value,
#    9523         margins=margins,
#    9524         dropna=dropna,
#    9525         margins_name=margins_name,
#    9526         observed=observed,
#    9527         sort=sort,
#    9528     )
#
# File ~/MADS-ML-PORTFOLIO-FBLAAK/portfolio-example-main/.venv/lib/python3.12/site-packages/pandas/core/reshape/pivot.py:102, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      99     table = concat(pieces, keys=keys, axis=1)
#     100     return table.__finalize__(data, method="pivot_table")
# --> 102 table = __internal_pivot_table(
#     103     data,
#     104     values,
#     105     index,
#     106     columns,
#     107     aggfunc,
#     108     fill_value,
#     109     margins,
#     110     dropna,
#     111     margins_name,
#     112     observed,
#     113     sort,
#     114 )
#     115 return table.__finalize__(data, method="pivot_table")
#
# File ~/MADS-ML-PORTFOLIO-FBLAAK/portfolio-example-main/.venv/lib/python3.12/site-packages/pandas/core/reshape/pivot.py:172, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     169     values = list(values)
#     171 observed_bool = False if observed is lib.no_default else observed
# --> 172 grouped = data.groupby(keys, observed=observed_bool, sort=sort, dropna=dropna)
#     173 if observed is lib.no_default and any(
#     174     ping._passed_categorical for ping in grouped._grouper.groupings
#     175 ):
#     176     warnings.warn(
#     177         "The default value of observed=False is deprecated and will change "
#     178         "to observed=True in a future version of pandas. Specify "
#    (...)    181         stacklevel=find_stack_level(),
#     182     )
#
# File ~/MADS-ML-PORTFOLIO-FBLAAK/portfolio-example-main/.venv/lib/python3.12/site-packages/pandas/core/frame.py:9190, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9187 if level is None and by is None:
#    9188     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9190 return DataFrameGroupBy(
#    9191     obj=self,
#    9192     keys=by,
#    9193     axis=axis,
#    9194     level=level,
#    9195     as_index=as_index,
#    9196     sort=sort,
#    9197     group_keys=group_keys,
#    9198     observed=observed,
#    9199     dropna=dropna,
#    9200 )
#
# File ~/MADS-ML-PORTFOLIO-FBLAAK/portfolio-example-main/.venv/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1330, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327 self.dropna = dropna
#    1329 if grouper is None:
# -> 1330     grouper, exclusions, obj = get_grouper(
#    1331         obj,
#    1332         keys,
#    1333         axis=axis,
#    1334         level=level,
#    1335         sort=sort,
#    1336         observed=False if observed is lib.no_default else observed,
#    1337         dropna=self.dropna,
#    1338     )
#    1340 if observed is lib.no_default:
#    1341     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File ~/MADS-ML-PORTFOLIO-FBLAAK/portfolio-example-main/.venv/lib/python3.12/site-packages/pandas/core/groupby/grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'optimizer'

# %%
import matplotlib.pyplot as plt

plt.scatter(df["train_loss"], df["test_loss"])
plt.xlabel("train loss")
plt.ylabel("test loss")
plt.title("Train vs Test Loss")

plt.plot([df.train_loss.min(), df.train_loss.max()],
         [df.train_loss.min(), df.train_loss.max()],
         linestyle="--")

plt.show()
